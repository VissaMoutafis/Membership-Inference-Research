# %% [markdown]
# # Membership Inference Attack Revisited
#
# Attack Model:
# - Fairly accurate target model $f_{target}(x)$, CIFAR-10 classification model
# - Attacker knows nothing about the architecture of the target model and creates his own NN architecture
# - Attacker has no information in the dataset (TODO). Attacker uses query based datapoint generation (check Shadow Datasets generation section)
# - $D_{target}$ training dataset and $\cup_i D_{shadow_i}$ dataset are disjoint
#
#
# The target is to prove that in a **complete black-box scenario** the attacker can exploit every minor model leak.
#
# CHANGES from previous session:
# - Target model is more generalized
# - The attack model doesn't use c-different classifier, but 1 sole classifier and the learning insances contain the datapoint's class as a feature
# - (TODO) The attack model only return a label as prediction and not a prediction vector
# - (TODO) Use data synthesis algorithm

# %%
import numpy as np
import matplotlib.pyplot as plt

import math
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tqdm.notebook import tqdm
import sys
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# ## F_target
#
# We create a simple CNN model.

# %%
def f_target(X_train, y_train, X_test=None, y_test=None, epochs=100):
  """
  Returns a trained target model, if test data are specified we will evaluate the model and print its accuracy
  """
  model = models.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
  model.add(layers.Conv2D(32, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.2))
  
  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.2))

  model.add(layers.Conv2D(128, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))

  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu'))
  model.add(layers.Dense(64, activation='relu'))
  model.add(layers.Dense(32, activation='relu'))
  model.add(layers.Dense(10))
  
  optimizer = keras.optimizers.Adam()
  model.compile(optimizer=optimizer,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
  if X_test is None or y_test is None:
    history = model.fit(X_train, y_train, epochs=epochs, 
                    validation_split=0.2)
  else:
    history = model.fit(X_train, y_train, epochs=epochs, 
                    validation_data=(X_test, y_test), verbose=True)
  return model

# %%
with tf.device('/gpu:0'):
  (train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
  train_images = train_images[:20000] # as the paper attack train wiht only 200 records
  train_labels = train_labels[:20000]
  # use the rest as testing - 'out' records
  test_images = np.concatenate((train_images[20000:], test_images))
  test_labels = np.concatenate((train_labels[20000:], test_labels))

# %%
with tf.device('/gpu:0'):
  target_model = f_target(train_images, train_labels)
# Out:
# Epoch 1/100
# 500/500 [==============================] - 8s 15ms/step - loss: 2.0946 - accuracy: 0.2221 - val_loss: 1.8032 - val_accuracy: 0.3350
# Epoch 2/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.7835 - accuracy: 0.3344 - val_loss: 1.6685 - val_accuracy: 0.3810
# Epoch 3/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.6531 - accuracy: 0.3914 - val_loss: 1.5946 - val_accuracy: 0.4195
# Epoch 4/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.5600 - accuracy: 0.4281 - val_loss: 1.5726 - val_accuracy: 0.4370
# Epoch 5/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.4867 - accuracy: 0.4621 - val_loss: 1.4471 - val_accuracy: 0.4880
# Epoch 6/100
# 500/500 [==============================] - 7s 13ms/step - loss: 1.4087 - accuracy: 0.4900 - val_loss: 1.4349 - val_accuracy: 0.4845
# Epoch 7/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.3559 - accuracy: 0.5176 - val_loss: 1.3947 - val_accuracy: 0.5013
# Epoch 8/100
# 500/500 [==============================] - 7s 13ms/step - loss: 1.3140 - accuracy: 0.5313 - val_loss: 1.2939 - val_accuracy: 0.5437
# Epoch 9/100
# 500/500 [==============================] - 7s 13ms/step - loss: 1.2673 - accuracy: 0.5511 - val_loss: 1.2614 - val_accuracy: 0.5630
# Epoch 10/100
# 500/500 [==============================] - 7s 13ms/step - loss: 1.2178 - accuracy: 0.5699 - val_loss: 1.2283 - val_accuracy: 0.5585
# Epoch 11/100
# 500/500 [==============================] - 7s 13ms/step - loss: 1.1742 - accuracy: 0.5891 - val_loss: 1.2772 - val_accuracy: 0.5530
# Epoch 12/100
# 500/500 [==============================] - 7s 13ms/step - loss: 1.1466 - accuracy: 0.5969 - val_loss: 1.2101 - val_accuracy: 0.5847
# Epoch 13/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.1068 - accuracy: 0.6083 - val_loss: 1.2420 - val_accuracy: 0.5763
# Epoch 14/100
# 500/500 [==============================] - 7s 13ms/step - loss: 1.0908 - accuracy: 0.6140 - val_loss: 1.1831 - val_accuracy: 0.5903
# Epoch 15/100
# 500/500 [==============================] - 7s 13ms/step - loss: 1.0515 - accuracy: 0.6304 - val_loss: 1.1661 - val_accuracy: 0.5953
# Epoch 16/100
# 500/500 [==============================] - 7s 13ms/step - loss: 1.0289 - accuracy: 0.6382 - val_loss: 1.1540 - val_accuracy: 0.5907
# Epoch 17/100
# 500/500 [==============================] - 7s 14ms/step - loss: 1.0286 - accuracy: 0.6387 - val_loss: 1.1552 - val_accuracy: 0.6062
# Epoch 18/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.9792 - accuracy: 0.6549 - val_loss: 1.1037 - val_accuracy: 0.6180
# Epoch 19/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.9419 - accuracy: 0.6711 - val_loss: 1.1314 - val_accuracy: 0.6258
# Epoch 20/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.9468 - accuracy: 0.6681 - val_loss: 1.1897 - val_accuracy: 0.5910
# Epoch 21/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.9189 - accuracy: 0.6815 - val_loss: 1.1771 - val_accuracy: 0.6158
# Epoch 22/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.8934 - accuracy: 0.6887 - val_loss: 1.0609 - val_accuracy: 0.6435
# Epoch 23/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.8835 - accuracy: 0.6934 - val_loss: 1.1373 - val_accuracy: 0.6135
# Epoch 24/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.8680 - accuracy: 0.6999 - val_loss: 1.0487 - val_accuracy: 0.6460
# Epoch 25/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.8383 - accuracy: 0.7111 - val_loss: 1.1295 - val_accuracy: 0.6250
# Epoch 26/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.8250 - accuracy: 0.7135 - val_loss: 1.1222 - val_accuracy: 0.6225
# Epoch 27/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.8229 - accuracy: 0.7169 - val_loss: 1.1530 - val_accuracy: 0.6283
# Epoch 28/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.7956 - accuracy: 0.7244 - val_loss: 1.1255 - val_accuracy: 0.6352
# Epoch 29/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.7960 - accuracy: 0.7251 - val_loss: 1.1280 - val_accuracy: 0.6392
# Epoch 30/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.7802 - accuracy: 0.7343 - val_loss: 1.1156 - val_accuracy: 0.6417
# Epoch 31/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.7583 - accuracy: 0.7347 - val_loss: 1.0904 - val_accuracy: 0.6413
# Epoch 32/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.7396 - accuracy: 0.7410 - val_loss: 1.1434 - val_accuracy: 0.6308
# Epoch 33/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.7457 - accuracy: 0.7411 - val_loss: 1.1552 - val_accuracy: 0.6460
# Epoch 34/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.7383 - accuracy: 0.7440 - val_loss: 1.1591 - val_accuracy: 0.6332
# Epoch 35/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.7129 - accuracy: 0.7534 - val_loss: 1.1239 - val_accuracy: 0.6440
# Epoch 36/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.7044 - accuracy: 0.7530 - val_loss: 1.1126 - val_accuracy: 0.6568
# Epoch 37/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.6995 - accuracy: 0.7613 - val_loss: 1.1529 - val_accuracy: 0.6310
# Epoch 38/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.6812 - accuracy: 0.7654 - val_loss: 1.1904 - val_accuracy: 0.6320
# Epoch 39/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.6669 - accuracy: 0.7684 - val_loss: 1.0963 - val_accuracy: 0.6570
# Epoch 40/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.6816 - accuracy: 0.7634 - val_loss: 1.1807 - val_accuracy: 0.6438
# Epoch 41/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.6630 - accuracy: 0.7721 - val_loss: 1.1026 - val_accuracy: 0.6420
# Epoch 42/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.6464 - accuracy: 0.7776 - val_loss: 1.1550 - val_accuracy: 0.6482
# Epoch 43/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.6483 - accuracy: 0.7766 - val_loss: 1.1507 - val_accuracy: 0.6580
# Epoch 44/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.6267 - accuracy: 0.7856 - val_loss: 1.1784 - val_accuracy: 0.6415
# Epoch 45/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.6213 - accuracy: 0.7844 - val_loss: 1.1020 - val_accuracy: 0.6485
# Epoch 46/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.6049 - accuracy: 0.7944 - val_loss: 1.1644 - val_accuracy: 0.6555
# Epoch 47/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.6051 - accuracy: 0.7939 - val_loss: 1.1905 - val_accuracy: 0.6545
# Epoch 48/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.6038 - accuracy: 0.7911 - val_loss: 1.2016 - val_accuracy: 0.6453
# Epoch 49/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.6021 - accuracy: 0.7959 - val_loss: 1.0928 - val_accuracy: 0.6612
# Epoch 50/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.5840 - accuracy: 0.8024 - val_loss: 1.2770 - val_accuracy: 0.6233
# Epoch 51/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.5805 - accuracy: 0.7997 - val_loss: 1.1886 - val_accuracy: 0.6503
# Epoch 52/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.5564 - accuracy: 0.8051 - val_loss: 1.2075 - val_accuracy: 0.6415
# Epoch 53/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.5682 - accuracy: 0.8033 - val_loss: 1.1745 - val_accuracy: 0.6492
# Epoch 54/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.5625 - accuracy: 0.8071 - val_loss: 1.2064 - val_accuracy: 0.6497
# Epoch 55/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.5635 - accuracy: 0.8069 - val_loss: 1.1722 - val_accuracy: 0.6535
# Epoch 56/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.5419 - accuracy: 0.8174 - val_loss: 1.1466 - val_accuracy: 0.6490
# Epoch 57/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.5351 - accuracy: 0.8186 - val_loss: 1.1357 - val_accuracy: 0.6628
# Epoch 58/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.5317 - accuracy: 0.8202 - val_loss: 1.1878 - val_accuracy: 0.6545
# Epoch 59/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.5336 - accuracy: 0.8199 - val_loss: 1.1855 - val_accuracy: 0.6522
# Epoch 60/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.5175 - accuracy: 0.8240 - val_loss: 1.2174 - val_accuracy: 0.6562
# Epoch 61/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.5225 - accuracy: 0.8202 - val_loss: 1.2669 - val_accuracy: 0.6417
# Epoch 62/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5205 - accuracy: 0.8257 - val_loss: 1.2244 - val_accuracy: 0.6505
# Epoch 63/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.5198 - accuracy: 0.8276 - val_loss: 1.1784 - val_accuracy: 0.6597
# Epoch 64/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.5115 - accuracy: 0.8273 - val_loss: 1.2704 - val_accuracy: 0.6490
# Epoch 65/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.4985 - accuracy: 0.8289 - val_loss: 1.2233 - val_accuracy: 0.6540
# Epoch 66/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.5043 - accuracy: 0.8291 - val_loss: 1.2087 - val_accuracy: 0.6540
# Epoch 67/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.5048 - accuracy: 0.8301 - val_loss: 1.2004 - val_accuracy: 0.6575
# Epoch 68/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.4748 - accuracy: 0.8374 - val_loss: 1.2664 - val_accuracy: 0.6550
# Epoch 69/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.4888 - accuracy: 0.8347 - val_loss: 1.2884 - val_accuracy: 0.6250
# Epoch 70/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.4886 - accuracy: 0.8322 - val_loss: 1.1828 - val_accuracy: 0.6532
# Epoch 71/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.4525 - accuracy: 0.8472 - val_loss: 1.3466 - val_accuracy: 0.6480
# Epoch 72/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.4944 - accuracy: 0.8358 - val_loss: 1.2626 - val_accuracy: 0.6570
# Epoch 73/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.4651 - accuracy: 0.8450 - val_loss: 1.2900 - val_accuracy: 0.6658
# Epoch 74/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.4691 - accuracy: 0.8411 - val_loss: 1.2759 - val_accuracy: 0.6450
# Epoch 75/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.4398 - accuracy: 0.8533 - val_loss: 1.2124 - val_accuracy: 0.6700
# Epoch 76/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.4697 - accuracy: 0.8398 - val_loss: 1.2300 - val_accuracy: 0.6472
# Epoch 77/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.4350 - accuracy: 0.8522 - val_loss: 1.2437 - val_accuracy: 0.6570
# Epoch 78/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.4423 - accuracy: 0.8528 - val_loss: 1.2257 - val_accuracy: 0.6595
# Epoch 79/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.4350 - accuracy: 0.8518 - val_loss: 1.2384 - val_accuracy: 0.6520
# Epoch 80/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.4200 - accuracy: 0.8592 - val_loss: 1.2874 - val_accuracy: 0.6633
# Epoch 81/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.4492 - accuracy: 0.8502 - val_loss: 1.2843 - val_accuracy: 0.6545
# Epoch 82/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.4441 - accuracy: 0.8537 - val_loss: 1.2441 - val_accuracy: 0.6555
# Epoch 83/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.4280 - accuracy: 0.8569 - val_loss: 1.3690 - val_accuracy: 0.6465
# Epoch 84/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.4487 - accuracy: 0.8510 - val_loss: 1.2639 - val_accuracy: 0.6560
# Epoch 85/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.4138 - accuracy: 0.8624 - val_loss: 1.3461 - val_accuracy: 0.6680
# Epoch 86/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.4335 - accuracy: 0.8592 - val_loss: 1.2466 - val_accuracy: 0.6633
# Epoch 87/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.4171 - accuracy: 0.8601 - val_loss: 1.2584 - val_accuracy: 0.6647
# Epoch 88/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.4080 - accuracy: 0.8619 - val_loss: 1.2946 - val_accuracy: 0.6607
# Epoch 89/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.4063 - accuracy: 0.8657 - val_loss: 1.2700 - val_accuracy: 0.6518
# Epoch 90/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.4093 - accuracy: 0.8681 - val_loss: 1.3595 - val_accuracy: 0.6400
# Epoch 91/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.4102 - accuracy: 0.8644 - val_loss: 1.3690 - val_accuracy: 0.6595
# Epoch 92/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.4120 - accuracy: 0.8662 - val_loss: 1.2840 - val_accuracy: 0.6528
# Epoch 93/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.3975 - accuracy: 0.8636 - val_loss: 1.2922 - val_accuracy: 0.6518
# Epoch 94/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.4094 - accuracy: 0.8624 - val_loss: 1.3212 - val_accuracy: 0.6540
# Epoch 95/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.3992 - accuracy: 0.8694 - val_loss: 1.2672 - val_accuracy: 0.6503
# Epoch 96/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.4008 - accuracy: 0.8701 - val_loss: 1.3252 - val_accuracy: 0.6597
# Epoch 97/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.3830 - accuracy: 0.8698 - val_loss: 1.3166 - val_accuracy: 0.6630
# Epoch 98/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.4028 - accuracy: 0.8678 - val_loss: 1.3990 - val_accuracy: 0.6482
# Epoch 99/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.3783 - accuracy: 0.8741 - val_loss: 1.3736 - val_accuracy: 0.6547
# Epoch 100/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.3910 - accuracy: 0.8698 - val_loss: 1.3546 - val_accuracy: 0.6575

# %% [markdown]
# ## Shadow dataset
# Define the $f_{shadow}(x)$ models and train them.

# %%
def f_shadow(X_train, y_train, X_test=None, y_test=None, epochs=50):
  model = models.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='tanh', input_shape=(32, 32, 3)))
  model.add(layers.Conv2D(32, (3, 3), activation='tanh'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.1))

  model.add(layers.Conv2D(64, (3, 3), activation='tanh'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.1))

  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='tanh'))
  model.add(layers.Dropout(0.1))
  model.add(layers.Dense(64, activation='tanh'))
  model.add(layers.Dense(32, activation='tanh'))

  model.add(layers.Dense(10)   )
  
  optimizer = keras.optimizers.Adam(learning_rate=0.001)
  model.compile(optimizer=optimizer,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
  if X_test is None or y_test is None:
    history = model.fit(X_train, y_train, epochs=epochs, 
                    validation_split=0.2)
  else:
    history = model.fit(X_train, y_train, epochs=epochs, 
                    validation_data=(X_test, y_test))
  return model

# %%
def divide_dataset(n_shadows, shadow_dataset_size, X, y):
  D_shadows = []
  rng = np.random.default_rng()
  for i in range(n_shadows):
    sample_i = np.random.choice(range(X.shape[0]), shadow_dataset_size, replace=False)
    assert np.unique(sample_i).shape[0] == shadow_dataset_size # sanity check
    D_shadows.append((X[sample_i, :], y[sample_i, :]))
  return D_shadows

# returns a list of 'n_shadows' datasets
def generate_shadow_dataset(target_model, n_shadows, shadow_dataset_size, n_classes, X_test=None, y_test=None):
  # in case we give test data we will just divide those to train the shadow models
  if X_test is not None and y_test is not None:
    return divide_dataset(n_shadows, shadow_dataset_size, X_test, y_test)
  
  
  # helper function to return a datapoint (for sure)
  def get_shadow_datapoint(c):
    X_i = None
    with tf.device('/gpu:0'):
      while X_i is None:
        X_i = synthesize(c, target_model, 1, 32*32*3, 0.8, 100, 20)
    return X_i
  
  D_shadows = []
  for i in range(n_shadows):
    print(f"Generating D_shadow_{i}")
    # uniformly generate X's for all of the classes (y's)
    X_shadow = np.asarray(
        [get_shadow_datapoint(i%n_classes) for i in range(shadow_dataset_size)]
    )
    y_shadow = np.asarray(
        [(i%n_classes) for i in range(shadow_dataset_size)]
    ).reshape((-1, 1))

    D_shadows.append((X_shadow, y_shadow))
  
  return D_shadows

def create_shadows(D_shadows):
  shadow_models = [] # shadow model list

  for D_shadow in D_shadows:
    # sample data to feed/evaluate the model
    X_shadow, y_shadow = D_shadow
    shadow_X_train, shadow_X_test, shadow_y_train, shadow_y_test = train_test_split(X_shadow, y_shadow, shuffle=True, test_size=0.33)

    # generate the shadow model
    shadow_model = f_shadow(shadow_X_train, shadow_y_train, shadow_X_test, shadow_y_test)

    D_shadow = (shadow_X_train, shadow_y_train), (shadow_X_test, shadow_y_test)
    shadow_models.append((shadow_model, D_shadow))

  return shadow_models # return a list where every item is (model, acc), train-data, test-data

# %%
# generate shadow datasets
D_shadows = generate_shadow_dataset(target_model, n_shadows=10, shadow_dataset_size=5000, n_classes=10, X_test=test_images, y_test=test_labels)

# %%
# train the shadow models
shadow_models = create_shadows(D_shadows)
# Out:
# Epoch 1/50
# 105/105 [==============================] - 2s 16ms/step - loss: 2.0948 - accuracy: 0.2307 - val_loss: 1.8802 - val_accuracy: 0.3188
# Epoch 2/50
# 105/105 [==============================] - 1s 12ms/step - loss: 1.8359 - accuracy: 0.3484 - val_loss: 1.8089 - val_accuracy: 0.3745
# Epoch 3/50
# 105/105 [==============================] - 1s 11ms/step - loss: 1.7134 - accuracy: 0.3925 - val_loss: 1.7060 - val_accuracy: 0.3988
# Epoch 4/50
# 105/105 [==============================] - 1s 11ms/step - loss: 1.6157 - accuracy: 0.4185 - val_loss: 1.6685 - val_accuracy: 0.4127
# Epoch 5/50
# 105/105 [==============================] - 1s 11ms/step - loss: 1.5026 - accuracy: 0.4651 - val_loss: 1.5794 - val_accuracy: 0.4400
# Epoch 6/50
# 105/105 [==============================] - 1s 12ms/step - loss: 1.4089 - accuracy: 0.5009 - val_loss: 1.5961 - val_accuracy: 0.4303
# Epoch 7/50
# 105/105 [==============================] - 1s 12ms/step - loss: 1.3430 - accuracy: 0.5260 - val_loss: 1.6014 - val_accuracy: 0.4594
# Epoch 8/50
# 105/105 [==============================] - 1s 12ms/step - loss: 1.2730 - accuracy: 0.5499 - val_loss: 1.4518 - val_accuracy: 0.4952
# Epoch 9/50
# 105/105 [==============================] - 1s 11ms/step - loss: 1.1166 - accuracy: 0.6179 - val_loss: 1.5390 - val_accuracy: 0.4691
# Epoch 10/50
# 105/105 [==============================] - 1s 12ms/step - loss: 1.0491 - accuracy: 0.6451 - val_loss: 1.4588 - val_accuracy: 0.4976
# Epoch 11/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.9139 - accuracy: 0.6901 - val_loss: 1.4899 - val_accuracy: 0.4982
# Epoch 12/50
# 105/105 [==============================] - 1s 11ms/step - loss: 0.8148 - accuracy: 0.7200 - val_loss: 1.5278 - val_accuracy: 0.4909
# Epoch 13/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.7624 - accuracy: 0.7430 - val_loss: 1.6032 - val_accuracy: 0.4885
# Epoch 14/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.6683 - accuracy: 0.7818 - val_loss: 1.5931 - val_accuracy: 0.4879
# Epoch 15/50
# 105/105 [==============================] - 1s 11ms/step - loss: 0.5804 - accuracy: 0.8087 - val_loss: 1.6594 - val_accuracy: 0.4745
# Epoch 16/50
# 105/105 [==============================] - 1s 11ms/step - loss: 0.5471 - accuracy: 0.8164 - val_loss: 1.6564 - val_accuracy: 0.4982
# Epoch 17/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.4923 - accuracy: 0.8427 - val_loss: 1.7264 - val_accuracy: 0.4891
# Epoch 18/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.4351 - accuracy: 0.8621 - val_loss: 1.7739 - val_accuracy: 0.4939
# Epoch 19/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.5115 - accuracy: 0.8176 - val_loss: 1.7741 - val_accuracy: 0.4897
# Epoch 20/50
# 105/105 [==============================] - 1s 11ms/step - loss: 0.4663 - accuracy: 0.8421 - val_loss: 1.9388 - val_accuracy: 0.4721
# Epoch 21/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.4055 - accuracy: 0.8693 - val_loss: 1.9078 - val_accuracy: 0.4897
# Epoch 22/50
# 105/105 [==============================] - 1s 11ms/step - loss: 0.3828 - accuracy: 0.8746 - val_loss: 1.8269 - val_accuracy: 0.4836
# Epoch 23/50
# 105/105 [==============================] - 1s 11ms/step - loss: 0.2966 - accuracy: 0.9018 - val_loss: 1.9097 - val_accuracy: 0.5000
# Epoch 24/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.2763 - accuracy: 0.9081 - val_loss: 1.8657 - val_accuracy: 0.4982
# Epoch 25/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.
50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2805 - accuracy: 0.9066 - val_loss: 2.1287 - val_accuracy: 0.4588
# Epoch 35/50
# 105/105 [==============================] - 1s 11ms/step - loss: 0.2726 - accuracy: 0.9131 - val_loss: 2.1854 - val_accuracy: 0.4594
# Epoch 36/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.2700 - accuracy: 0.9107 - val_loss: 2.2141 - val_accuracy: 0.4582
# Epoch 37/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.2160 - accuracy: 0.9269 - val_loss: 2.2508 - val_accuracy: 0.4661
# Epoch 38/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2204 - accuracy: 0.9251 - val_loss: 2.1901 - val_accuracy: 0.4733
# Epoch 39/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.2565 - accuracy: 0.9131 - val_loss: 2.3419 - val_accuracy: 0.4679
# Epoch 40/50
# 105/105 [==============================] - 1s 11ms/step - loss: 0.2256 - accuracy: 0.9239 - val_loss: 2.2676 - val_accuracy: 0.4648
# Epoch 41/50
# 105/105 [==============================] - 1s 11ms/step - loss: 0.2834 - accuracy: 0.9021 - val_loss: 2.3371 - val_accuracy: 0.4545
# Epoch 42/50
# 105/105 [==============================] - 1s 11ms/step - loss: 0.2690 - accuracy: 0.9033 - val_loss: 2.3124 - val_accuracy: 0.4539
# Epoch 43/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.2208 - accuracy: 0.9239 - val_loss: 2.3127 - val_accuracy: 0.4642
# Epoch 44/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.3082 - accuracy: 0.8922 - val_loss: 2.4180 - val_accuracy: 0.4552
# Epoch 45/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.4370 - accuracy: 0.8501 - val_loss: 2.3049 - val_accuracy: 0.4491
# Epoch 46/50
# 105/105 [==============================] - 1s 11ms/step - loss: 0.3787 - accuracy: 0.8728 - val_loss: 2.3722 - val_accuracy: 0.4545
# Epoch 47/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.3550 - accuracy: 0.8824 - val_loss: 2.3311 - val_accuracy: 0.4570
# Epoch 48/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.1973 - accuracy: 0.9370 - val_loss: 2.3584 - val_accuracy: 0.4515
# Epoch 49/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.2030 - accuracy: 0.9379 - val_loss: 2.3218 - val_accuracy: 0.4576
# Epoch 50/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.1708 - accuracy: 0.9454 - val_loss: 2.3582 - val_accuracy: 0.4570
# Epoch 1/50
# 105/105 [==============================] - 2s 15ms/step - loss: 2.1606 - accuracy: 0.1928 - val_loss: 1.9387 - val_accuracy: 0.2794
# Epoch 2/50
# 105/105 [==============================] - 1s 12ms/step - loss: 1.8817 - accuracy: 0.3099 - val_loss: 1.7894 - val_accuracy: 0.3400
# Epoch 3/50
# 105/105 [==============================] - 1s 13ms/step - loss: 1.7699 - accuracy: 0.3552 - val_loss: 1.7849 - val_accuracy: 0.3461
# Epoch 4/50
# 105/105 [==============================] - 1s 13ms/step - loss: 1.6922 - accuracy: 0.3779 - val_loss: 1.6868 - val_accuracy: 0.3879
# Epoch 5/50
# 105/105 [==============================] - 1s 13ms/step - loss: 1.5989 - accuracy: 0.4200 - val_loss: 1.6580 - val_accuracy: 0.3976
# Epoch 6/50
# 105/105 [==============================] - 1s 12ms/step - loss: 1.5488 - accuracy: 0.4442 - val_loss: 1.6311 - val_accuracy: 0.4079
# Epoch 7/50
# 105/105 [==============================] - 1s 13ms/step - loss: 1.4694 - accuracy: 0.4663 - val_loss: 1.6030 - val_accuracy: 0.4145
# Epoch 8/50
# 105/105 [==============================] - 1s 12ms/step - loss: 1.3589 - accuracy: 0.5042 - val_loss: 1.5571 - val_accuracy: 0.4297
# Epoch 9/50
# 105/105 [==============================] - 1s 13ms/step - loss: 1.2689 - accuracy: 0.5433 - val_loss: 1.5390 - val_accuracy: 0.4612
# Epoch 10/50
# 105/105 [==============================] - 1s 12ms/step - loss: 1.2225 - accuracy: 0.5696 - val_loss: 1.5524 - val_accuracy: 0.4655
# Epoch 11/50
# 105/105 [==============================] - 1s 12ms/step - loss: 1.1262 - accuracy: 0.6066 - val_loss: 1.5727 - val_accuracy: 0.4588
# Epoch 12/50
# 105/105 [==============================] - 1s 13ms/step - loss: 1.0568 - accuracy: 0.6340 - val_loss: 1.5874 - val_accuracy: 0.4509
# Epoch 13/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.9579 - accuracy: 0.6651 - val_loss: 1.5448 - val_accuracy: 0.4794
# Epoch 14/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.8560 - accuracy: 0.7069 - val_loss: 1.6563 - val_accuracy: 0.4606
# Epoch 15/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.7929 - accuracy: 0.7358 - val_loss: 1.5833 - val_accuracy: 0.4648
# Epoch 16/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.7214 - accuracy: 0.7472 - val_loss: 1.6746 - val_accuracy: 0.4630
# Epoch 17/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.6561 - accuracy: 0.7827 - val_loss: 1.7119 - val_accuracy: 0.4491
# Epoch 18/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.6596 - accuracy: 0.7806 - val_loss: 1.7396 - val_accuracy: 0.4606
# Epoch 19/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.6142 - accuracy: 0.7931 - val_loss: 1.9351 - val_accuracy: 0.4164
# Epoch 20/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.5740 - accuracy: 0.8024 - val_loss: 1.8716 - val_accuracy: 0.4418
# Epoch 21/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.5020 - accuracy: 0.8296 - val_loss: 1.8246 - val_accuracy: 0.4588
# Epoch 22/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.4541 - accuracy: 0.8501 - val_loss: 1.8551 - val_accuracy: 0.4661
# Epoch 23/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.4394 - accuracy: 0.8469 - val_loss: 1.8983 - val_accuracy: 0.4624
# Epoch 24/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.4138 - accuracy: 0.8603 - val_loss: 1.8913 - val_accuracy: 0.4552
# Epoch 25/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.3666 - accuracy: 0.8809 - val_loss: 1.9608 - val_accuracy: 0.4582
# Epoch 26/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.3966 - accuracy: 0.8630 - val_loss: 1.9695 - val_accuracy: 0.4394
# Epoch 27/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.3110 - accuracy: 0.8967 - val_loss: 1.9557 - val_accuracy: 0.4667
# Epoch 28/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.3007 - accuracy: 0.9042 - val_loss: 2.0577 - val_accuracy: 0.4436
# Epoch 29/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.3156 - accuracy: 0.8997 - val_loss: 2.2097 - val_accuracy: 0.4321
# Epoch 30/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.3788 - accuracy: 0.8687 - val_loss: 2.2077 - val_accuracy: 0.4358
# Epoch 31/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.4148 - accuracy: 0.8570 - val_loss: 2.1387 - val_accuracy: 0.4406
# Epoch 32/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.2977 - accuracy: 0.8985 - val_loss: 2.1892 - val_accuracy: 0.4558
# Epoch 33/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.2396 - accuracy: 0.9245 - val_loss: 2.1567 - val_accuracy: 0.4594
# Epoch 34/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.2405 - accuracy: 0.9230 - val_loss: 2.1859 - val_accuracy: 0.4461
# Epoch 35/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.2232 - accuracy: 0.9254 - val_loss: 2.1885 - val_accuracy: 0.4697
# Epoch 36/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.2291 - accuracy: 0.9224 - val_loss: 2.2959 - val_accuracy: 0.4515
# Epoch 37/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.2416 - accuracy: 0.9206 - val_loss: 2.2442 - val_accuracy: 0.4545
# Epoch 38/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.4125 - accuracy: 0.8621 - val_loss: 2.2585 - val_accuracy: 0.4285
# Epoch 39/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.3485 - accuracy: 0.8773 - val_loss: 2.3023 - val_accuracy: 0.4321
# Epoch 40/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.3587 - accuracy: 0.8737 - val_loss: 2.3007 - val_accuracy: 0.4503
# Epoch 41/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.3692 - accuracy: 0.8737 - val_loss: 2.3786 - val_accuracy: 0.4442
# Epoch 42/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2527 - accuracy: 0.9155 - val_loss: 2.3415 - val_accuracy: 0.4606
# Epoch 43/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.
50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.3189 - accuracy: 0.8991 - val_loss: 1.8177 - val_accuracy: 0.5121
# Epoch 23/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2643 - accuracy: 0.9140 - val_loss: 1.8407 - val_accuracy: 0.5121
# Epoch 24/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.3109 - accuracy: 0.8931 - val_loss: 1.8821 - val_accuracy: 0.4964
# Epoch 25/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.2915 - accuracy: 0.9027 - val_loss: 1.9057 - val_accuracy: 0.5061
# Epoch 26/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.3397 - accuracy: 0.8845 - val_loss: 1.9376 - val_accuracy: 0.4861
# Epoch 27/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2894 - accuracy: 0.9033 - val_loss: 1.9017 - val_accuracy: 0.5018
# Epoch 28/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.2498 - accuracy: 0.9182 - val_loss: 1.8986 - val_accuracy: 0.5297
# Epoch 29/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.2901 - accuracy: 0.9084 - val_loss: 2.0173 - val_accuracy: 0.4891
# Epoch 30/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2468 - accuracy: 0.9254 - val_loss: 1.9825 - val_accuracy: 0.5091
# Epoch 31/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2774 - accuracy: 0.9081 - val_loss: 2.0424 - val_accuracy: 0.4836
# Epoch 32/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.2786 - accuracy: 0.9090 - val_loss: 2.0694 - val_accuracy: 0.4909
# Epoch 33/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2763 - accuracy: 0.9060 - val_loss: 2.0324 - val_accuracy: 0.5139
# Epoch 34/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.2062 - accuracy: 0.9349 - val_loss: 2.0532 - val_accuracy: 0.4933
# Epoch 35/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2381 - accuracy: 0.9200 - val_loss: 2.1112 - val_accuracy: 0.4915
# Epoch 36/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.2267 - accuracy: 0.9248 - val_loss: 2.2073 - val_accuracy: 0.4909
# Epoch 37/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.2507 - accuracy: 0.9182 - val_loss: 2.1448 - val_accuracy: 0.5006
# Epoch 38/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.2196 - accuracy: 0.9254 - val_loss: 2.2432 - val_accuracy: 0.4988
# Epoch 39/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2278 - accuracy: 0.9260 - val_loss: 2.1857 - val_accuracy: 0.4952
# Epoch 40/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2354 - accuracy: 0.9227 - val_loss: 2.2587 - val_accuracy: 0.4727
# Epoch 41/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.2311 - accuracy: 0.9245 - val_loss: 2.1920 - val_accuracy: 0.5018
# Epoch 42/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.2129 - accuracy: 0.9275 - val_loss: 2.2863 - val_accuracy: 0.4964
# Epoch 43/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2027 - accuracy: 0.9319 - val_loss: 2.2789 - val_accuracy: 0.5042
# Epoch 44/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.1746 - accuracy: 0.9427 - val_loss: 2.1931 - val_accuracy: 0.5127
# Epoch 45/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.1275 - accuracy: 0.9600 - val_loss: 2.2549 - val_accuracy: 0.5036
# Epoch 46/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.2874 - accuracy: 0.9048 - val_loss: 2.2696 - val_accuracy: 0.4873
# Epoch 47/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.2734 - accuracy: 0.9101 - val_loss: 2.3014 - val_accuracy: 0.4788
# Epoch 48/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2769 - accuracy: 0.9084 - val_loss: 2.3779 - val_accuracy: 0.4800
# Epoch 49/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.1885 - accuracy: 0.9358 - val_loss: 2.2122 - val_accuracy: 0.4952
# Epoch 50/50
# 105/105 [==============================] - 1s 12ms/step - loss: 0.2068 - accuracy: 0.9290 - val_loss: 2.3024 - val_accuracy: 0.4885
# Epoch 1/50
# 105/105 [==============================] - 2s 15ms/step - loss: 2.0760 - accuracy: 0.2272 - val_loss: 1.8438 - val_accuracy: 0.3291
# Epoch 2/50
# 105/105 [==============================] - 1s 13ms/step - loss: 1
50
# 105/105 [==============================] - 1s 13ms/step - loss: 1.0420 - accuracy: 0.6433 - val_loss: 1.6110 - val_accuracy: 0.4479
# Epoch 12/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.9626 - accuracy: 0.6687 - val_loss: 1.6362 - val_accuracy: 0.4358
# Epoch 13/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.8820 - accuracy: 0.6907 - val_loss: 1.6327 - val_accuracy: 0.4515
# Epoch 14/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.7852 - accuracy: 0.7316 - val_loss: 1.6031 - val_accuracy: 0.4709
# Epoch 15/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.7039 - accuracy: 0.7639 - val_loss: 1.6627 - val_accuracy: 0.4576
# Epoch 16/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.6544 - accuracy: 0.7890 - val_loss: 1.6855 - val_accuracy: 0.4600
# Epoch 17/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.6227 - accuracy: 0.7839 - val_loss: 1.7064 - val_accuracy: 0.4642
# Epoch 18/50
# 105/105 [==============================] - 2s 14ms/step - loss: 0.5670 - accuracy: 0.8048 - val_loss: 1.7018 - val_accuracy: 0.4661
# Epoch 19/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.5943 - accuracy: 0.7982 - val_loss: 1.7254 - val_accuracy: 0.4667
# Epoch 20/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.4613 - accuracy: 0.8436 - val_loss: 1.8159 - val_accuracy: 0.4727
# Epoch 21/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.5019 - accuracy: 0.8373 - val_loss: 1.8118 - val_accuracy: 0.4679
# Epoch 22/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.4282 - accuracy: 0.8621 - val_loss: 1.9076 - val_accuracy: 0.4679
# Epoch 23/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.4073 - accuracy: 0.8633 - val_loss: 1.9215 - val_accuracy: 0.4636
# Epoch 24/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.3532 - accuracy: 0.8863 - val_loss: 1.9375 - val_accuracy: 0.4673
# Epoch 25/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.3271 - accuracy: 0.8973 - val_loss: 1.9092 - val_accuracy: 0.4764
# Epoch 26/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.3076 - accuracy: 0.8964 - val_loss: 2.1333 - val_accuracy: 0.4436
# Epoch 27/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.3920 - accuracy: 0.8660 - val_loss: 2.1121 - val_accuracy: 0.4473
# Epoch 28/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.3836 - accuracy: 0.8687 - val_loss: 2.1447 - val_accuracy: 0.4521
# Epoch 29/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.4034 - accuracy: 0.8636 - val_loss: 2.1191 - val_accuracy: 0.4636
# Epoch 30/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.3482 - accuracy: 0.8755 - val_loss: 2.1510 - val_accuracy: 0.4339
# Epoch 31/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.3045 - accuracy: 0.8976 - val_loss: 2.1842 - val_accuracy: 0.4564
# Epoch 32/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2618 - accuracy: 0.9122 - val_loss: 2.0928 - val_accuracy: 0.4770
# Epoch 33/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2285 - accuracy: 0.9251 - val_loss: 2.1616 - val_accuracy: 0.4485
# Epoch 34/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2894 - accuracy: 0.9048 - val_loss: 2.2581 - val_accuracy: 0.4467
# Epoch 35/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.3207 - accuracy: 0.8890 - val_loss: 2.2247 - val_accuracy: 0.4527
# Epoch 36/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2506 - accuracy: 0.9164 - val_loss: 2.2535 - val_accuracy: 0.4539
# Epoch 37/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2796 - accuracy: 0.9075 - val_loss: 2.2430 - val_accuracy: 0.4576
# Epoch 38/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.2680 - accuracy: 0.9087 - val_loss: 2.2127 - val_accuracy: 0.4661
# Epoch 39/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.2584 - accuracy: 0.9158 - val_loss: 2.2907 - val_accuracy: 0.4515
# Epoch 40/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2502 - accuracy: 0.9143 - val_loss: 2.3397 - val_accuracy: 0.4606
# Epoch 41/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.
50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.5733 - accuracy: 0.7964 - val_loss: 1.7955 - val_accuracy: 0.4679
# Epoch 21/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.5598 - accuracy: 0.8090 - val_loss: 1.8367 - val_accuracy: 0.4515
# Epoch 22/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.5183 - accuracy: 0.8310 - val_loss: 1.8293 - val_accuracy: 0.4570
# Epoch 23/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.4681 - accuracy: 0.8400 - val_loss: 1.9538 - val_accuracy: 0.4382
# Epoch 24/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.4422 - accuracy: 0.8522 - val_loss: 1.8762 - val_accuracy: 0.4703
# Epoch 25/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.3793 - accuracy: 0.8794 - val_loss: 1.9203 - val_accuracy: 0.4733
# Epoch 26/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.3951 - accuracy: 0.8690 - val_loss: 2.0052 - val_accuracy: 0.4479
# Epoch 27/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.4023 - accuracy: 0.8597 - val_loss: 1.9971 - val_accuracy: 0.4673
# Epoch 28/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.3948 - accuracy: 0.8707 - val_loss: 2.0582 - val_accuracy: 0.4521
# Epoch 29/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.3399 - accuracy: 0.8904 - val_loss: 2.0675 - val_accuracy: 0.4455
# Epoch 30/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.3497 - accuracy: 0.8854 - val_loss: 2.1454 - val_accuracy: 0.4461
# Epoch 31/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.3074 - accuracy: 0.9000 - val_loss: 2.0947 - val_accuracy: 0.4612
# Epoch 32/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.3139 - accuracy: 0.8982 - val_loss: 2.1083 - val_accuracy: 0.4515
# Epoch 33/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2375 - accuracy: 0.9236 - val_loss: 2.1184 - val_accuracy: 0.4661
# Epoch 34/50
# ...
# Epoch 40/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.1624 - accuracy: 0.9484 - val_loss: 2.3377 - val_accuracy: 0.4733
# Epoch 41/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.1482 - accuracy: 0.9519 - val_loss: 2.3647 - val_accuracy: 0.4703
# Epoch 42/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2116 - accuracy: 0.9325 - val_loss: 2.4672 - val_accuracy: 0.4436
# Epoch 43/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.3213 - accuracy: 0.8967 - val_loss: 2.5067 - val_accuracy: 0.4424
# Epoch 44/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.2298 - accuracy: 0.9245 - val_loss: 2.4024 - val_accuracy: 0.4618
# Epoch 45/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2121 - accuracy: 0.9239 - val_loss: 2.3915 - val_accuracy: 0.4715
# Epoch 46/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2132 - accuracy: 0.9242 - val_loss: 2.4630 - val_accuracy: 0.4509
# Epoch 47/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2090 - accuracy: 0.9293 - val_loss: 2.5361 - val_accuracy: 0.4473
# Epoch 48/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.1813 - accuracy: 0.9415 - val_loss: 2.4076 - val_accuracy: 0.4764
# Epoch 49/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.1398 - accuracy: 0.9579 - val_loss: 2.4484 - val_accuracy: 0.4703
# Epoch 50/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.1252 - accuracy: 0.9603 - val_loss: 2.4335 - val_accuracy: 0.4739
# Epoch 1/50
# 105/105 [==============================] - 2s 16ms/step - loss: 2.0840 - accuracy: 0.2266 - val_loss: 1.8681 - val_accuracy: 0.3267
# Epoch 2/50
# 105/105 [==============================] - 1s 13ms/step - loss: 1.8043 - accuracy: 0.3516 - val_loss: 1.8256 - val_accuracy: 0.3467
# Epoch 3/50
# 105/105 [==============================] - 1s 14ms/step - loss: 1.7131 - accuracy: 0.3755 - val_loss: 1.7668 - val_accuracy: 0.3685
# Epoch 4/50
# 105/105 [==============================] - 1s 13ms/step - loss: 1.6155 - accuracy: 0.4125 - val_loss: 1.7146 - val_accuracy: 0.3879
# Epoch 5/50
# 105/105 [==============================] - 1s 14ms/step - loss: 1.5012 - accuracy: 0.4603 - val_loss: 1.7001 - val_accuracy: 0.3909
# Epoch 6/50
# 105/105 [==============================] - 1s 14ms/step - loss: 1.3901 - accuracy: 0.5066 - val_loss: 1.6232 - val_accuracy: 0.4139
# Epoch 7/50
# 105/105 [==============================] - 1s 14ms/step - loss: 1.3195 - accuracy: 0.5352 - val_loss: 1.6081 - val_accuracy: 0.4242
# Epoch 8/50
# 105/105 [==============================] - 1s 14ms/step - loss: 1.2418 - accuracy: 0.5588 - val_loss: 1.5698 - val_accuracy: 0.4491
# Epoch 9/50
# 105/105 [==============================] - 1s 13ms/step - loss: 1.1643 - accuracy: 0.5940 - val_loss: 1.5784 - val_accuracy: 0.4467
# Epoch 10/50
# 105/105 [==============================] - 1s 13ms/step - loss: 1.0544 - accuracy: 0.6301 - val_loss: 1.5801 - val_accuracy: 0.4582
# Epoch 11/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.9656 - accuracy: 0.6648 - val_loss: 1.6209 - val_accuracy: 0.4618
# Epoch 12/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.8490 - accuracy: 0.7179 - val_loss: 1.6287 - val_accuracy: 0.4564
# Epoch 13/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.8384 - accuracy: 0.7182 - val_loss: 1.6205 - val_accuracy: 0.4739
# Epoch 14/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.7495 - accuracy: 0.7445 - val_loss: 1.6474 - val_accuracy: 0.4739
# Epoch 15/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.6607 - accuracy: 0.7752 - val_loss: 1.7176 - val_accuracy: 0.4642
# Epoch 16/50
# 105/105 [==============================] - 2s 14ms/step - loss: 0.6200 - accuracy: 0.7958 - val_loss: 1.7116 - val_accuracy: 0.4703
# Epoch 17/50
# 105/105 [==============================] - 2s 14ms/step - loss: 0.5608 - accuracy: 0.8107 - val_loss: 1.7608 - val_accuracy: 0.4588
# Epoch 18/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.4916 - accuracy: 0.8433 - val_loss: 1.7829 - val_accuracy: 0.4830
# Epoch 19/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.4523 - accuracy: 0.8499 - val_loss: 1.8299 - val_accuracy: 0.4606
# Epoch 20/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.4498 - accuracy: 0.8499 - val_loss: 1.8466 - val_accuracy: 0.4764
# Epoch 21/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.3689 - accuracy: 0.8791 - val_loss: 1.8612 - val_accuracy: 0.4697
# Epoch 22/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.3100 - accuracy: 0.9036 - val_loss: 1.8972 - val_accuracy: 0.4861
# Epoch 23/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.3689 - accuracy: 0.8719 - val_loss: 2.0173 - val_accuracy: 0.4576
# Epoch 24/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.4115 - accuracy: 0.8588 - val_loss: 2.0097 - val_accuracy: 0.4764
# Epoch 25/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.4109 - accuracy: 0.8606 - val_loss: 2.0064 - val_accuracy: 0.4685
# Epoch 26/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2975 - accuracy: 0.9069 - val_loss: 2.0188 - val_accuracy: 0.4727
# Epoch 27/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.3431 - accuracy: 0.8854 - val_loss: 2.0680 - val_accuracy: 0.4721
# Epoch 28/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.3785 - accuracy: 0.8752 - val_loss: 2.1006 - val_accuracy: 0.4685
# Epoch 29/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.2850 - accuracy: 0.8994 - val_loss: 2.2108 - val_accuracy: 0.4612
# Epoch 30/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.2739 - accuracy: 0.9033 - val_loss: 2.1381 - val_accuracy: 0.4745
# Epoch 31/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2545 - accuracy: 0.9164 - val_loss: 2.1876 - val_accuracy: 0.4600
# Epoch 32/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2455 - accuracy: 0.9233 - val_loss: 2.2733 - val_accuracy: 0.4564
# Epoch 33/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.2284 - accuracy: 0.9224 - val_loss: 2.2300 - val_accuracy: 0.4588
# Epoch 34/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2545 - accuracy: 0.9099 - val_loss: 2.2242 - val_accuracy: 0.4788
# Epoch 35/50
# 105/105 [==============================] - 2s 14ms/step - loss: 0.3044 - accuracy: 0.9018 - val_loss: 2.3403 - val_accuracy: 0.4358
# Epoch 36/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.2322 - accuracy: 0.9212 - val_loss: 2.3110 - val_accuracy: 0.4630
# Epoch 37/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.2006 - accuracy: 0.9325 - val_loss: 2.2872 - val_accuracy: 0.4679
# Epoch 38/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2186 - accuracy: 0.9290 - val_loss: 2.4027 - val_accuracy: 0.4600
# Epoch 39/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.2330 - accuracy: 0.9260 - val_loss: 2.2954 - val_accuracy: 0.4721
# Epoch 40/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.2559 - accuracy: 0.9066 - val_loss: 2.3288 - val_accuracy: 0.4642
# Epoch 41/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.3505 - accuracy: 0.8761 - val_loss: 2.4573 - val_accuracy: 0.4539
# Epoch 42/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.3568 - accuracy: 0.8734 - val_loss: 2.4154 - val_accuracy: 0.4564
# Epoch 43/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2478 - accuracy: 0.9185 - val_loss: 2.2742 - val_accuracy: 0.4497
# Epoch 44/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2394 - accuracy: 0.9191 - val_loss: 2.3902 - val_accuracy: 0.4612
# Epoch 45/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.2201 - accuracy: 0.9278 - val_loss: 2.3954 - val_accuracy: 0.4727
# Epoch 46/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2269 - accuracy: 0.9173 - val_loss: 2.5038 - val_accuracy: 0.4564
# Epoch 47/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.1786 - accuracy: 0.9436 - val_loss: 2.4291 - val_accuracy: 0.4576
# Epoch 48/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.1574 - accuracy: 0.9463 - val_loss: 2.4214 - val_accuracy: 0.4527
# Epoch 49/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.1391 - accuracy: 0.9576 - val_loss: 2.4891 - val_accuracy: 0.4582
# Epoch 50/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2431 - accuracy: 0.9212 - val_loss: 2.5107 - val_accuracy: 0.4588
# Epoch 1/50
# 105/105 [==============================] - 2s 16ms/step - loss: 2.0666 - accuracy: 0.2334 - val_loss: 1.9335 - val_accuracy: 0.2915
# Epoch 2/50
# 105/105 [==============================] - 1s 13ms/step - loss: 1.8593 - accuracy: 0.3248 - val_loss: 1.8142 - val_accuracy: 0.3582
# Epoch 3/50
# 105/105 [==============================] - 1s 14ms/step - loss: 1.7378 - accuracy: 0.3707 - val_loss: 1.7616 - val_accuracy: 0.3576
# Epoch 4/50
# 105/105 [==============================] - 1s 14ms/step - loss: 1.7199 - accuracy: 0.3707 - val_loss: 1.6842 - val_accuracy: 0.3848
# Epoch 5/50
# 105/105 [==============================] - 1s 13ms/step - loss: 1.6107 - accuracy: 0.4176 - val_loss: 1.7508 - val_accuracy: 0.3533
# Epoch 6/50
# 105/105 [==============================] - 1s 14ms/step - loss: 1.5588 - accuracy: 0.4418 - val_loss: 1.6643 - val_accuracy: 0.3788
# Epoch 7/50
# 105/105 [==============================] - 1s 13ms/step - loss: 1.4973 - accuracy: 0.4621 - val_loss: 1.5969 - val_accuracy: 0.4200
# Epoch 8/50
# 105/105 [==============================] - 1s 13ms/step - loss: 1.3967 - accuracy: 0.5024 - val_loss: 1.6409 - val_accuracy: 0.4079
# Epoch 9/50
# 105/105 [==============================] - 1s 14ms/step - loss: 1.3206 - accuracy: 0.5349 - val_loss: 1.5672 - val_accuracy: 0.4455
# Epoch 10/50
# 105/105 [==============================] - 1s 14ms/step - loss: 1.2231 - accuracy: 0.5690 - val_loss: 1.5524 - val_accuracy: 0.4630
# Epoch 11/50
# 105/105 [==============================] - 1s 13ms/step - loss: 1.1700 - accuracy: 0.5931 - val_loss: 1.5686 - val_accuracy: 0.4570
# Epoch 12/50
# 105/105 [==============================] - 1s 13ms/step - loss: 1.0792 - accuracy: 0.6197 - val_loss: 1.5435 - val_accuracy: 0.4612
# Epoch 13/50
# 105/105 [==============================] - 2s 14ms/step - loss: 0.9375 - accuracy: 0.6815 - val_loss: 1.5411 - val_accuracy: 0.4739
# Epoch 14/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.8525 - accuracy: 0.7215 - val_loss: 1.5603 - val_accuracy: 0.4703
# Epoch 15/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.8333 - accuracy: 0.7146 - val_loss: 1.6011 - val_accuracy: 0.4794
# Epoch 16/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.7797 - accuracy: 0.7301 - val_loss: 1.6044 - val_accuracy: 0.4788
# Epoch 17/50
# 105/105 [==============================] - 2s 14ms/step - loss: 0.6588 - accuracy: 0.7851 - val_loss: 1.6679 - val_accuracy: 0.4636
# Epoch 18/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.6032 - accuracy: 0.8036 - val_loss: 1.6778 - val_accuracy: 0.4661
# Epoch 19/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.5725 - accuracy: 0.8107 - val_loss: 1.7420 - val_accuracy: 0.4752
# Epoch 20/50
# 105/105 [==============================] - 2s 14ms/step - loss: 0.5544 - accuracy: 0.8131 - val_loss: 1.7285 - val_accuracy: 0.4709
# Epoch 21/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.5251 - accuracy: 0.8296 - val_loss: 1.8300 - val_accuracy: 0.4515
# Epoch 22/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.4463 - accuracy: 0.8525 - val_loss: 1.7691 - val_accuracy: 0.4709
# Epoch 23/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.4168 - accuracy: 0.8681 - val_loss: 1.8271 - val_accuracy: 0.4794
# Epoch 24/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.4524 - accuracy: 0.8484 - val_loss: 1.8198 - val_accuracy: 0.4721
# Epoch 25/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.4317 - accuracy: 0.8463 - val_loss: 1.9017 - val_accuracy: 0.4570
# Epoch 26/50
# 105/105 [==============================] - 2s 14ms/step - loss: 0.3721 - accuracy: 0.8800 - val_loss: 1.9050 - val_accuracy: 0.4745
# Epoch 27/50
# 105/105 [==============================] - 2s 15ms/step - loss: 0.3467 - accuracy: 0.8872 - val_loss: 2.0005 - val_accuracy: 0.4703
# Epoch 28/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.3675 - accuracy: 0.8752 - val_loss: 2.1456 - val_accuracy: 0.4442
# Epoch 29/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.3313 - accuracy: 0.8890 - val_loss: 2.0501 - val_accuracy: 0.4709
# Epoch 30/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2877 - accuracy: 0.9081 - val_loss: 2.0065 - val_accuracy: 0.4903
# Epoch 31/50
# 105/105 [==============================] - 2s 14ms/step - loss: 0.2871 - accuracy: 0.9072 - val_loss: 2.0810 - val_accuracy: 0.4667
# Epoch 32/50
# 105/105 [==============================] - 2s 14ms/step - loss: 0.2805 - accuracy: 0.9101 - val_loss: 2.0252 - val_accuracy: 0.4842
# Epoch 33/50
# 105/105 [==============================] - 2s 15ms/step - loss: 0.1937 - accuracy: 0.9397 - val_loss: 2.1106 - val_accuracy: 0.4800
# Epoch 34/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.2181 - accuracy: 0.9340 - val_loss: 2.0734 - val_accuracy: 0.4885
# Epoch 35/50
# 105/105 [==============================] - 2s 15ms/step - loss: 0.2300 - accuracy: 0.9245 - val_loss: 2.2313 - val_accuracy: 0.4691
# Epoch 36/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.2701 - accuracy: 0.9084 - val_loss: 2.3000 - val_accuracy: 0.4394
# Epoch 37/50
# 105/105 [==============================] - 2s 15ms/step - loss: 0.2959 - accuracy: 0.9006 - val_loss: 2.1567 - val_accuracy: 0.4715
# Epoch 38/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.2370 - accuracy: 0.9203 - val_loss: 2.2660 - val_accuracy: 0.4497
# Epoch 39/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.2140 - accuracy: 0.9260 - val_loss: 2.3343 - val_accuracy: 0.4552
# Epoch 40/50
# 105/105 [==============================] - 2s 14ms/step - loss: 0.2296 - accuracy: 0.9203 - val_loss: 2.4136 - val_accuracy: 0.4673
# Epoch 41/50
# 105/105 [==============================] - 2s 14ms/step - loss: 0.2695 - accuracy: 0.9060 - val_loss: 2.3105 - val_accuracy: 0.4691
# Epoch 42/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.2843 - accuracy: 0.9084 - val_loss: 2.2621 - val_accuracy: 0.4824
# Epoch 43/50
# 105/105 [==============================] - 2s 15ms/step - loss: 0.2177 - accuracy: 0.9287 - val_loss: 2.3483 - val_accuracy: 0.4739
# Epoch 44/50
# 105/105 [==============================] - 2s 14ms/step - loss: 0.2534 - accuracy: 0.9167 - val_loss: 2.2415 - val_accuracy: 0.4788
# Epoch 45/50
# 105/105 [==============================] - 2s 15ms/step - loss: 0.2007 - accuracy: 0.9293 - val_loss: 2.2936 - val_accuracy: 0.4909
# Epoch 46/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.2543 - accuracy: 0.9087 - val_loss: 2.3314 - val_accuracy: 0.4679
# Epoch 47/50
# 105/105 [==============================] - 1s 13ms/step - loss: 0.1995 - accuracy: 0.9373 - val_loss: 2.4789 - val_accuracy: 0.4691
# Epoch 48/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.2008 - accuracy: 0.9304 - val_loss: 2.4422 - val_accuracy: 0.4594
# Epoch 49/50
# 105/105 [==============================] - 2s 14ms/step - loss: 0.1845 - accuracy: 0.9370 - val_loss: 2.5397 - val_accuracy: 0.4497
# Epoch 50/50
# 105/105 [==============================] - 1s 14ms/step - loss: 0.2118 - accuracy: 0.9272 - val_loss: 2.3795 - val_accuracy: 0.4739

# %%
# helper function to prepare each shadow dataset batch
def prepare_batch(shadow_model, X, y, in_D=True):
  #decide membership
  y_member = np.ones(shape=(y.shape[0], 1)) if in_D else np.zeros(shape=(y.shape[0], 1))
  
  # get probability vector
  prob_layer = layers.Softmax() # probability layer implementing softmax for mapping NN results to probabilities in [0, 1]
  prob_vec = prob_layer(shadow_model(X)).numpy()
  
  # return an instance <actual class, prob_vec from shadow model, 'in'/'out' D_target membership> 
  return np.concatenate((y.reshape(-1, 1), prob_vec, y_member), axis=1)

def generate_attack_dataset(shadow_models):
  # input is a list where items are model, (X_train, y_train), (X_test, y_test)

  D_attack = None
  # D_attack_i format = <class, prob_vec, membership label (1 or 0)> 
  for shadow_model, ((X_train, y_train), (X_test, y_test)) in shadow_models:
    s = min(X_train.shape[0], X_test.shape[0])
    print(s)
    batch = np.concatenate((
        prepare_batch(shadow_model, X_train[:s], y_train[:s], True), # members of shadow dataset 
        prepare_batch(shadow_model, X_test[:s], y_test[:s], False)   # non members of shadow dataset
    ))   

    D_attack = np.concatenate((D_attack, batch)) if D_attack is not None else batch  

  return D_attack

# %%
D_attack = generate_attack_dataset(shadow_models)
# Out:
# 1650
# 1650
# 1650
# 1650
# 1650
# 1650
# 1650
# 1650
# 1650
# 1650

# %%
def __f_attack(X_train, y_train, X_test, y_test, epochs=100):
  print(X_train.shape, X_test.shape)
  model = models.Sequential()
  model.add(layers.Dense(11, activation='relu', input_shape=(X_train.shape[1], )))
  model.add(layers.Dense(110, activation='relu'))
  model.add(layers.Dense(1100, activation='relu'))
  model.add(layers.Dense(1, activation='sigmoid'))
  
  optimizer = keras.optimizers.Adam()
  model.compile(optimizer=optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy'])
  history = model.fit(X_train, y_train, epochs=epochs, 
                    validation_data=(X_test, y_test), verbose=True)
  
  return model


def f_attack(X, y):
  # X_i = (class, probability vector, )
  classes = np.unique(train_labels) # all class labels
  with tf.device('/gpu:0'):
  # split to train and test datasets
    X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=0.25)
    attack_model = __f_attack(X_train, y_train, X_test, y_test) 
  return attack_model

# %%
attack_model = f_attack(D_attack[:, :-1], D_attack[:, -1])
# Out:
# (24750, 11) (8250, 11)
# Epoch 1/100
# 774/774 [==============================] - 5s 5ms/step - loss: 0.5544 - accuracy: 0.7146 - val_loss: 0.4715 - val_accuracy: 0.7882
# Epoch 2/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4867 - accuracy: 0.7771 - val_loss: 0.4698 - val_accuracy: 0.7896
# Epoch 3/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4740 - accuracy: 0.7863 - val_loss: 0.4608 - val_accuracy: 0.8015
# Epoch 4/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4705 - accuracy: 0.7872 - val_loss: 0.4690 - val_accuracy: 0.7994
# Epoch 5/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4684 - accuracy: 0.7873 - val_loss: 0.4591 - val_accuracy: 0.7970
# Epoch 6/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4658 - accuracy: 0.7903 - val_loss: 0.4516 - val_accuracy: 0.8027
# Epoch 7/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4636 - accuracy: 0.7907 - val_loss: 0.4480 - val_accuracy: 0.8011
# Epoch 8/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4634 - accuracy: 0.7891 - val_loss: 0.4506 - val_accuracy: 0.8006
# Epoch 9/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4607 - accuracy: 0.7912 - val_loss: 0.4479 - val_accuracy: 0.8029
# Epoch 10/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4591 - accuracy: 0.7926 - val_loss: 0.4509 - val_accuracy: 0.8024
# Epoch 11/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4583 - accuracy: 0.7928 - val_loss: 0.4483 - val_accuracy: 0.8025
# Epoch 12/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4574 - accuracy: 0.7922 - val_loss: 0.4549 - val_accuracy: 0.8018
# Epoch 13/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4555 - accuracy: 0.7946 - val_loss: 0.4542 - val_accuracy: 0.7994
# Epoch 14/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4538 - accuracy: 0.7951 - val_loss: 0.4503 - val_accuracy: 0.8058
# Epoch 15/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4541 - accuracy: 0.7936 - val_loss: 0.4511 - val_accuracy: 0.8016
# Epoch 16/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4538 - accuracy: 0.7940 - val_loss: 0.4486 - val_accuracy: 0.8027
# Epoch 17/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4520 - accuracy: 0.7953 - val_loss: 0.4466 - val_accuracy: 0.8035
# Epoch 18/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4515 - accuracy: 0.7946 - val_loss: 0.4445 - val_accuracy: 0.8056
# Epoch 19/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4526 - accuracy: 0.7942 - val_loss: 0.4508 - val_accuracy: 0.8032
# Epoch 20/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4502 - accuracy: 0.7943 - val_loss: 0.4475 - val_accuracy: 0.8029
# Epoch 21/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4504 - accuracy: 0.7943 - val_loss: 0.4483 - val_accuracy: 0.8028
# Epoch 22/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4495 - accuracy: 0.7956 - val_loss: 0.4506 - val_accuracy: 0.8044
# Epoch 23/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4500 - accuracy: 0.7946 - val_loss: 0.4537 - val_accuracy: 0.7982
# Epoch 24/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4480 - accuracy: 0.7969 - val_loss: 0.4427 - val_accuracy: 0.8078
# Epoch 25/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4493 - accuracy: 0.7953 - val_loss: 0.4451 - val_accuracy: 0.8025
# Epoch 26/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4479 - accuracy: 0.7947 - val_loss: 0.4431 - val_accuracy: 0.8042
# Epoch 27/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4472 - accuracy: 0.7968 - val_loss: 0.4451 - val_accuracy: 0.8059
# Epoch 28/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4471 - accuracy: 0.7964 - val_loss: 0.4459 - val_accuracy: 0.8032
# Epoch 29/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4475 - accuracy: 0.7959 - val_loss: 0.4521 - val_accuracy: 0.8002
# Epoch 30/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4458 - accuracy: 0.7959 - val_loss: 0.4494 - val_accuracy: 0.8008
# Epoch 31/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4455 - accuracy: 0.7968 - val_loss: 0.4409 - val_accuracy: 0.8048
# Epoch 32/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4454 - accuracy: 0.7973 - val_loss: 0.4447 - val_accuracy: 0.8050
# Epoch 33/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4454 - accuracy: 0.7958 - val_loss: 0.4431 - val_accuracy: 0.8056
# Epoch 34/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4448 - accuracy: 0.7960 - val_loss: 0.4401 - val_accuracy: 0.8058
# Epoch 35/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4450 - accuracy: 0.7969 - val_loss: 0.4412 - val_accuracy: 0.8064
# Epoch 36/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4446 - accuracy: 0.7959 - val_loss: 0.4412 - val_accuracy: 0.8041
# Epoch 37/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4429 - accuracy: 0.7983 - val_loss: 0.4465 - val_accuracy: 0.8010
# Epoch 38/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4439 - accuracy: 0.7974 - val_loss: 0.4418 - val_accuracy: 0.8024
# Epoch 39/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4446 - accuracy: 0.7956 - val_loss: 0.4587 - val_accuracy: 0.8021
# Epoch 40/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4428 - accuracy: 0.7967 - val_loss: 0.4421 - val_accuracy: 0.8073
# Epoch 41/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4433 - accuracy: 0.7971 - val_loss: 0.4405 - val_accuracy: 0.8032
# Epoch 42/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4439 - accuracy: 0.7954 - val_loss: 0.4425 - val_accuracy: 0.8038
# Epoch 43/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4425 - accuracy: 0.7975 - val_loss: 0.4684 - val_accuracy: 0.7745
# Epoch 44/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4432 - accuracy: 0.7968 - val_loss: 0.4432 - val_accuracy: 0.8053
# Epoch 45/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4431 - accuracy: 0.7962 - val_loss: 0.4453 - val_accuracy: 0.8052
# Epoch 46/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4415 - accuracy: 0.7979 - val_loss: 0.4398 - val_accuracy: 0.8062
# Epoch 47/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4414 - accuracy: 0.7972 - val_loss: 0.4369 - val_accuracy: 0.8038
# Epoch 48/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4409 - accuracy: 0.7979 - val_loss: 0.4513 - val_accuracy: 0.8029
# Epoch 49/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4420 - accuracy: 0.7962 - val_loss: 0.4406 - val_accuracy: 0.8041
# Epoch 50/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4413 - accuracy: 0.7981 - val_loss: 0.4394 - val_accuracy: 0.8053
# Epoch 51/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4407 - accuracy: 0.7983 - val_loss: 0.4394 - val_accuracy: 0.8048
# Epoch 52/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4399 - accuracy: 0.7989 - val_loss: 0.4373 - val_accuracy: 0.8068
# Epoch 53/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4398 - accuracy: 0.7989 - val_loss: 0.4502 - val_accuracy: 0.8025
# Epoch 54/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4402 - accuracy: 0.7976 - val_loss: 0.4397 - val_accuracy: 0.8036
# Epoch 55/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4395 - accuracy: 0.7973 - val_loss: 0.4448 - val_accuracy: 0.7852
# Epoch 56/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4395 - accuracy: 0.7978 - val_loss: 0.4404 - val_accuracy: 0.8059
# Epoch 57/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4397 - accuracy: 0.7984 - val_loss: 0.4465 - val_accuracy: 0.8033
# Epoch 58/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4390 - accuracy: 0.7989 - val_loss: 0.4468 - val_accuracy: 0.8035
# Epoch 59/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4394 - accuracy: 0.7983 - val_loss: 0.4425 - val_accuracy: 0.8032
# Epoch 60/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.
100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4337 - accuracy: 0.8007 - val_loss: 0.4430 - val_accuracy: 0.8030
# Epoch 91/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4336 - accuracy: 0.7990 - val_loss: 0.4424 - val_accuracy: 0.8055
# Epoch 92/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4334 - accuracy: 0.7991 - val_loss: 0.4469 - val_accuracy: 0.8038
# Epoch 93/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4323 - accuracy: 0.7998 - val_loss: 0.4417 - val_accuracy: 0.8041
# Epoch 94/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4324 - accuracy: 0.8006 - val_loss: 0.4476 - val_accuracy: 0.8041
# Epoch 95/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4322 - accuracy: 0.7995 - val_loss: 0.4488 - val_accuracy: 0.8030
# Epoch 96/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4324 - accuracy: 0.7996 - val_loss: 0.4459 - val_accuracy: 0.8051
# Epoch 97/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4321 - accuracy: 0.8012 - val_loss: 0.4405 - val_accuracy: 0.8036
# Epoch 98/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4327 - accuracy: 0.8001 - val_loss: 0.4401 - val_accuracy: 0.8041
# Epoch 99/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4318 - accuracy: 0.8009 - val_loss: 0.4484 - val_accuracy: 0.8052
# Epoch 100/100
# 774/774 [==============================] - 4s 5ms/step - loss: 0.4326 - accuracy: 0.8004 - val_loss: 0.4426 - val_accuracy: 0.8059

# %%
def evaluate_attack(attack_model, X_attack, y_attack, n_classes):
  acc_per_class = []
  for c in range(n_classes):
    class_instances = X_attack[:, 0] == c # get same class samples
    test_loss, test_acc = attack_model.evaluate(X_attack[class_instances, :], y_attack[class_instances], verbose=0)
    acc_per_class.append(test_acc)
    print(f"class-{c+1}: {test_acc}")
  return acc_per_class

# %%
# create a test dataset 

D_out = prepare_batch(target_model, test_images, test_labels, False)
D_in = prepare_batch(target_model, train_images[:10000], train_labels[:10000], True)
print("Testing with 'in' data only:")
res_in = evaluate_attack(attack_model, D_in[:, :-1], D_in[:, -1], 10)

print("\nTesting with 'out' data only:")
res_out = evaluate_attack(attack_model, D_out[:, :-1], D_out[:, -1], 10)

print("\nTesting with all prev data: ")
res_all = evaluate_attack(attack_model, np.concatenate((D_out[:, :-1], D_in[:, :-1])), np.concatenate((D_out[:, -1], D_in[:, -1])), 10)
# Out:
# Testing with 'in' data only:
# class-1: 0.7930348515510559
# class-2: 0.6878849864006042
# class-3: 0.7761628031730652
# class-4: 0.6594488024711609
# class-5: 0.8418418169021606
# class-6: 0.7598719596862793
# class-7: 0.7514563202857971
# class-8: 0.8031967878341675
# class-9: 0.9180487990379333
# class-10: 0.932721734046936
#
# Testing with 'out' data only:
# class-1: 0.5210000276565552
# class-2: 0.5239999890327454
# class-3: 0.6520000100135803
# class-4: 0.7990000247955322
# class-5: 0.5979999899864197
# class-6: 0.6549999713897705
# class-7: 0.5130000114440918
# class-8: 0.5440000295639038
# class-9: 0.34700000286102295
# class-10: 0.3630000054836273
#
# Testing with all prev data:
# class-1: 0.6573566198348999
# class-2: 0.6048632264137268
# class-3: 0.7150590419769287
# class-4: 0.7286706566810608
# class-5: 0.7198599576950073
# class-6: 0.7057304978370667
# class-7: 0.6339901685714722
# class-8: 0.6736631393432617
# class-9: 0.6360493898391724
# class-10: 0.6451287269592285
